# %%
import json
import pandas as pd
from pathlib import Path

# %%
# Path ke file JSON hasil generate QA
json_path = Path("output/qa_cleaning_peraturan_2025.json")

# Load JSON
with json_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

print("Total QA:", len(data["qa_pairs"]))
# Out:
# Total QA: 119

# %%
df = pd.DataFrame(data["qa_pairs"])
df.head()
# Out:
#   context                                           question  \
# 0          Apakah syarat penyelenggaraan program sarjana ...
# 1          Apakah program studi baru harus melalui proses...
# 2          Apa saja status akreditasi yang diberikan oleh...
# 3          Apakah ada lembaga lain selain Badan Akreditas...
# 4          Apa saja jenis program sarjana dan sarjana ter...
#
#                                               answer  pasal  ayat
# 0  Ya, penyelenggaraan program studi harus mempun...    3.0     1
# 1  Ya, program studi baru harus terakreditasi ses...    3.0     2
# 2  Status terakreditasi, tidak terakreditasi, ata...    3.0     3
# 3  Ya, Lembaga Akreditasi Mandiri dan lembaga akr...    3.0     3
# 4  Jenis-jenis program tersebut meliputi kelas re...    3.0     4

# %%
# Output CSV
csv_path = Path("output_csv/qa_cleaning_peraturan_2025.csv")

df.to_csv(
    csv_path,
    index=False,
    encoding="utf-8-sig" 
)
print("✅ CSV berhasil dibuat:", csv_path)
# Out:
# ✅ CSV berhasil dibuat: output_csv\qa_cleaning_peraturan_2025.csv
